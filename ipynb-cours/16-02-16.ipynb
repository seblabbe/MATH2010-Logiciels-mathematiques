# %%
from __future__ import division

# %% [markdown]
# # Chapitres 1 à 4
# Quelques ajouts dans les sections déjà vues...

# %% [markdown]
# ### 3.1 Nombres rationels
# Une autre façon de créer un nombre rationnel

# %%
5 / 2
# Out:
# 2.5

# %%
from sympy import Rational
Rational(5,2)
# Out:
# 5/2

# %%
from sympy import S
S?

# %%
type(S(5))
# Out:
# sympy.core.numbers.Integer

# %%
S(5)/2
# Out:
# 5/2

# %%
S('13/2') + S(5)/7
# Out:
# 101/14

# %% [markdown]
# ### 3.2 Nombres complexes

# %%
from sympy import arg,re,im,I

# %%
a = 3 + 5*I

# %%
re(a)
# Out:
# 3

# %%
im(a)
# Out:
# 5

# %%
arg(a).n()
# Out:
# 1.03037682652431

# %%
abs(a)
# Out:
# sqrt(34)

# %% [markdown]
# ### 4.2 Définir les variables symboliques x_1, x_2, ... x_n

# %%
from sympy import symbols

# %%
x3,x4,x5,x6,x7 = symbols('x3:8')

# %%
x3 + x4+ 6 *x7
# Out:
# x3 + x4 + 6*x7

# %% [markdown]
# # Initialisation

# %% [markdown]
# Importer toutes les fonctions de Sympy:

# %%
from sympy import *
init_printing(pretty_print=True, use_latex='mathjax')

# %% [markdown]
# Importer quelques variables du module abc:

# %%
#from sympy.abc import *   # à éviter
from sympy.abc import a,b,c,n,t,u,v,w,x,y,z

# %% [markdown]
# # 5 Résolution d'équations

# %% [markdown]
# ### 5.1 Définir une équation

# %% [markdown]
# Définir l'équation $x=3$

# %%
eq1 = Eq(x, 3)

# %% [markdown]
# Définir l'équation $x^2+y^2=16$

# %%
eq2 = Eq(x**2+y**2, 16)

# %% [markdown]
# ### 5.2 Résoudre une équation

# %%
solve(eq1, x)
# Out:
# [3]

# %%
solve(eq2, y)
# Out:
# ⎡    ___________     ___________⎤
# ⎢   ╱    2          ╱    2      ⎥
# ⎣-╲╱  - x  + 16 , ╲╱  - x  + 16 ⎦

# %% [markdown]
# Résoudre l'équation $x^2+2x=4$

# %%
solve(Eq(x**2+2*x, 4))
# Out:
# ⎡       ___      ___    ⎤
# ⎣-1 + ╲╱ 5 , - ╲╱ 5  - 1⎦

# %% [markdown]
# ### 5.3 Résoudre un système d'équations

# %% [markdown]
# Résoudre le système $x+y=34$, $xy=34$

# %%
eq1 = Eq(x+y, 34)
eq2 = Eq(x*y, 34)
systeme = [eq1, eq2]
solve(systeme)
# Out:
# ⎡⎧       _____            _____     ⎫  ⎧     _____              _____     ⎫⎤
# ⎢⎨x: - ╲╱ 255  + 17, y: ╲╱ 255  + 17⎬, ⎨x: ╲╱ 255  + 17, y: - ╲╱ 255  + 17⎬⎥
# ⎣⎩                                  ⎭  ⎩                                  ⎭⎦

# %% [markdown]
# Résoudre le système $x+y=34$, $xy^2=34$

# %%
eq1 = Eq(x+y, 34)
eq2 = Eq(x*y**2, 34)
systeme = [eq1, eq2]
solve(systeme)
# Out:
# ⎡⎧         ⎛                    ⎛                       ______________________
# ⎢⎪         ⎜      ⎛      ___  ⎞ ⎜      ⎛      ___  ⎞ 3 ╱              _______
# ⎢⎪     2/3 ⎜136   ⎝1 - ╲╱ 3 ⋅ⅈ⎠⋅⎝136 + ⎝1 - ╲╱ 3 ⋅ⅈ⎠⋅╲╱  38845 + 51⋅╲╱ 13791 ⋅
# ⎢⎪   17   ⋅⎜─── + ────────────────────────────────────────────────────────────
# ⎢⎨         ⎝ 3                                                102
# ⎢⎪x: ─────────────────────────────────────────────────────────────────────────
# ⎢⎪                                                     ______________________
# ⎢⎪                                    ⎛      ___  ⎞ 3 ╱            _______
# ⎣⎩                                    ⎝1 - ╲╱ 3 ⋅ⅈ⎠⋅╲╱  2285 + 3⋅╲╱ 13791 ⋅ⅈ
#
# __⎞    ________________________⎞           ⎛                      ⎛
#   ⎟ 3 ╱              _______   ⎟           ⎜        ⎛      ___  ⎞ ⎜     ⎛
# ⅈ ⎠⋅╲╱  38845 + 51⋅╲╱ 13791 ⋅ⅈ ⎟       2/3 ⎜  136   ⎝1 - ╲╱ 3 ⋅ⅈ⎠⋅⎝68 + ⎝-1 +
# ───────────────────────────────⎟     17   ⋅⎜- ─── + ──────────────────────────
#                                ⎠           ⎝   3
# ────────────────────────────────, y: ─────────────────────────────────────────
#
#                                                                        ⎛
#                                                                        ⎝1 - ╲╱
#
#             ________________________⎞    ________________________⎞⎫  ⎧
#   ___  ⎞ 3 ╱              _______   ⎟ 3 ╱              _______   ⎟⎪  ⎪
# ╲╱ 3 ⋅ⅈ⎠⋅╲╱  38845 + 51⋅╲╱ 13791 ⋅ⅈ ⎠⋅╲╱  38845 + 51⋅╲╱ 13791 ⋅ⅈ ⎟⎪  ⎪     2/3
# ─────────────────────────────────────────────────────────────────⎟⎪  ⎪   17
#                   102                                            ⎠⎬  ⎨
# ──────────────────────────────────────────────────────────────────⎪, ⎪x: ─────
#           ______________________                                  ⎪  ⎪
# ___  ⎞ 3 ╱            _______                                     ⎪  ⎪
#  3 ⋅ⅈ⎠⋅╲╱  2285 + 3⋅╲╱ 13791 ⋅ⅈ                                   ⎭  ⎩
#
#  ⎛                    ⎛                       ________________________⎞    ___
#  ⎜      ⎛      ___  ⎞ ⎜      ⎛      ___  ⎞ 3 ╱              _______   ⎟ 3 ╱
#  ⎜136   ⎝1 + ╲╱ 3 ⋅ⅈ⎠⋅⎝136 + ⎝1 + ╲╱ 3 ⋅ⅈ⎠⋅╲╱  38845 + 51⋅╲╱ 13791 ⋅ⅈ ⎠⋅╲╱  38
# ⋅⎜─── + ──────────────────────────────────────────────────────────────────────
#  ⎝ 3                                                102
# ──────────────────────────────────────────────────────────────────────────────
#                                              ______________________
#                             ⎛      ___  ⎞ 3 ╱            _______
#                             ⎝1 + ╲╱ 3 ⋅ⅈ⎠⋅╲╱  2285 + 3⋅╲╱ 13791 ⋅ⅈ
#
# _____________________⎞           ⎛                      ⎛
#            _______   ⎟           ⎜        ⎛      ___  ⎞ ⎜     ⎛       ___  ⎞ 3
# 845 + 51⋅╲╱ 13791 ⋅ⅈ ⎟       2/3 ⎜  136   ⎝1 + ╲╱ 3 ⋅ⅈ⎠⋅⎝68 + ⎝-1 - ╲╱ 3 ⋅ⅈ⎠⋅╲
# ─────────────────────⎟     17   ⋅⎜- ─── + ────────────────────────────────────
#                      ⎠           ⎝   3
# ──────────────────────, y: ───────────────────────────────────────────────────
#
#                                                              ⎛      ___  ⎞ 3 ╱
#                                                              ⎝1 + ╲╱ 3 ⋅ⅈ⎠⋅╲╱
#
#   ________________________⎞    ________________________⎞⎫
#  ╱              _______   ⎟ 3 ╱              _______   ⎟⎪
# ╱  38845 + 51⋅╲╱ 13791 ⋅ⅈ ⎠⋅╲╱  38845 + 51⋅╲╱ 13791 ⋅ⅈ ⎟⎪  ⎧
# ───────────────────────────────────────────────────────⎟⎪  ⎪        3 ____ 3 ╱
#         102                                            ⎠⎬  ⎪   68   ╲╱ 17 ⋅╲╱
# ────────────────────────────────────────────────────────⎪, ⎨x: ── - ──────────
# ______________________                                  ⎪  ⎪   3
#             _______                                     ⎪  ⎪
#  2285 + 3⋅╲╱ 13791 ⋅ⅈ                                   ⎭  ⎩
#
#
#
# ______________________
#             _______                     2/3                                  2
#  2285 + 3⋅╲╱ 13791 ⋅ⅈ              68⋅17                 34             68⋅17
# ────────────────────── - ───────────────────────────, y: ── + ────────────────
#      3                        ______________________     3         ___________
#                            3 ╱            _______               3 ╱
#                          3⋅╲╱  2285 + 3⋅╲╱ 13791 ⋅ⅈ           3⋅╲╱  2285 + 3⋅╲
#
#                                                ⎤
#                                                ⎥
#                         ______________________⎫⎥
# /3            3 ____ 3 ╱            _______   ⎪⎥
#               ╲╱ 17 ⋅╲╱  2285 + 3⋅╲╱ 13791 ⋅ⅈ ⎪⎥
# ─────────── + ────────────────────────────────⎬⎥
# ___________                  3                ⎪⎥
#  _______                                      ⎪⎥
# ╱ 13791 ⋅ⅈ                                    ⎭⎦

# %% [markdown]
# ### 5.4 Syntaxe abrégée

# %% [markdown]
# Résoudre les systèmes ci-haut avec la syntaxe abrégée

# %%
solve([x+y-34, x*y-34])
# Out:
# ⎡⎧       _____            _____     ⎫  ⎧     _____              _____     ⎫⎤
# ⎢⎨x: - ╲╱ 255  + 17, y: ╲╱ 255  + 17⎬, ⎨x: ╲╱ 255  + 17, y: - ╲╱ 255  + 17⎬⎥
# ⎣⎩                                  ⎭  ⎩                                  ⎭⎦

# %% [markdown]
# ### 5.5 Trouver les racines d'une fonction

# %% [markdown]
# $$3x^2  + 52x - 265$$

# %%
roots(3*x**2+52*x-265)
# Out:
# ⎧         ______         ______        ⎫
# ⎪  26   ╲╱ 1471        ╲╱ 1471    26   ⎪
# ⎨- ── + ────────: 1, - ──────── - ──: 1⎬
# ⎪  3       3              3       3    ⎪
# ⎩                                      ⎭

# %% [markdown]
# $$3x^3  + 52x - 265$$

# %%
r1,r2,r3 = roots(3*x**3+52*x-265)

# %%
r1.n(), r2.n(), r3.n()
# Out:
# (3.20205243239924, -1.60102621619962 - -5.00231827937895⋅(-1)⋅ⅈ, -1.6010262161
# 9962 + 5.00231827937895⋅ⅈ)

# %% [markdown]
# ## 6 Tracer une fonction

# %%
# %matplotlib inline

# %% [markdown]
# ### 6.1 Tracer une fonction R -> R

# %% [markdown]
# $$f(x) = x^2$$

# %%
f = x**2
plot(x**2, (x,-20,20))

# %% [markdown]
# $$g(x) = {3x^2  + 52x - 265 \over (x - 7)(x - 1)(x + 34)}$$

# %%
g = (3*x**2+52*x-265) / ((x-7)*(x-1)*(x+34))
plot(g, (x,-40,10), xlim=(-40, 10), ylim=(-2,2))

# %% [markdown]
# Approximer les racines de $$x^3 + 2x^2 - 1$$ avec un dessin

# %%
plot(x**3+2*x**2-1, (x,-2,1), ylim=(-1,1))

# %%
roots(x**3+2*x**2-1)
# Out:
# ⎧               ___         ___       ⎫
# ⎪         1   ╲╱ 5        ╲╱ 5    1   ⎪
# ⎨-1: 1, - ─ + ─────: 1, - ───── - ─: 1⎬
# ⎪         2     2           2     2   ⎪
# ⎩                                     ⎭

# %% [markdown]
# ### 6.2 Tracer plusieurs fonctions R -> R

# %% [markdown]
# Tracer $f(x)$ en vert et $g(x)$ en jaune dans le même dessin

# %%
plot(f, g)

# %% [markdown]
# ### 6.3 Tracer une fonction R^2 -> R

# %%
from sympy.plotting import plot3d

# %% [markdown]
# $$x^2+y^2$$

# %%
j

# %% [markdown]
# $$x^2-y^2$$

# %%
plot3d(x**2-y**2)

# %% [markdown]
# $$(x^2-y^2)\sin(x)$$

# %%
plot3d((x**2-y**2)*sin(x))

# %% [markdown]
# ### 6.4 Dessiner une fonction R -> R^2

# %%
from sympy.plotting import plot_parametric

# %% [markdown]
# $$x = \sin(t)$$
# $$y = \cos(t)$$

# %%
plot_parametric(sin(t), cos(t))

# %% [markdown]
# Butterfly curve (transcendental)
#
# $$x = \sin(t) \left(e^{\cos(t)} - 2\cos(4t) - \sin^5\left({t \over 12}\right)\right)$$
# $$y = \cos(t) \left(e^{\cos(t)} - 2\cos(4t) - \sin^5\left({t \over 12}\right)\right)$$
#
# Voir: https://en.wikipedia.org/wiki/Butterfly_curve_%28transcendental%29

# %%
x = sin(t)*(E**cos(t)-2*cos(4*t)-sin(t/12)**5)
y = cos(t)*(E**cos(t)-2*cos(4*t)-sin(t/12)**5)
plot_parametric(x, y)

# %%
from IPython.display import Image
url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f5/Param_02.jpg/800px-Param_02.jpg'
Image(url=url, width=500)
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f5/Param_02.jpg/800px-Param_02.jpg" width="500"/>

# %% [markdown]
# ### 6.5 Dessiner une fonction R -> R^3

# %%
from sympy.plotting import plot3d_parametric_line

# %% [markdown]
# \begin{align} x(u)&= \cos(u)\\ y(u)&=\sin(u)\\ z(u)&=u\end{align}

# %%
x = cos(u)
y = sin(u)
z = u
plot3d_parametric_line(x,y,z)

# %% [markdown]
# \begin{align} x(u)&= u \cos(u)\\ y(u)&=\sin(u)\\ z(u)&=u\end{align}

# %%
x = u*cos(u)
y = u*sin(u)
z = u
plot3d_parametric_line(x,y,z)

# %% [markdown]
# ### 6.6 Dessiner une fonction R^2 -> R^3

# %%
from sympy.plotting import plot3d_parametric_surface

# %% [markdown]
# \begin{align}
# X &= \cos(u)(R+r\cos(v))\\
# Y &= \sin(u)(R+r\cos(v))\\
# Z &= r\sin(v)
# \end{align}

# %%
from sympy.abc import u,v
R = 5
r = 2
X = cos(u)*(R+r*cos(v))
Y = sin(u)*(R+r*cos(v))
Z = r*sin(v)
plot3d_parametric_surface(X, Y, Z, (u, -.5, 4), (v, -5, 5))

# %% [markdown]
# $$\vec r(\theta,\phi) = (\cos\theta \sin\phi, \sin\theta \sin \phi, \cos\phi), \quad 0 \leq \theta < 2\pi, 0 \leq \phi \leq \pi.$$

# %%
from sympy.abc import theta,phi
from sympy import pi,cos,sin
x = cos(theta)*sin(phi)
y = sin(theta)*sin(phi)
z = cos(theta)
plot3d_parametric_surface(x,y,z,(theta,0,pi), (phi,0,pi))

# %% [markdown]
# ### 6.7 Dessiner les solutions d'une équation implicite

# %% [markdown]
# Tracer les solutions de l'équation $$x^2+y^2+xy-2x =5$$

# %%
from sympy import plot_implicit
eq = Eq(x**2+y**2+x*y-2*x, 5)
plot_implicit(eq)

# %% [markdown]
# ### 6.8 Tracer une région de R^2

# %% [markdown]
# Tracer la région délimitée par $$y>2x+1, y<5x, x+y<5$$

# %% [markdown]
# ### 6.9 Dessiner une fonction complexe avec mpmath

# %%
#from sympy import mpmath    # Sympy (installation normale)
import mpmath               # SageMath

# %% [markdown]
# Tracer la fonction complexe identité $$f(z)=z$$

# %%
from mpmath import cplot

# %%
cplot(lambda z:z)

# %% [markdown]
# Tracer la fonction complexe $$f(z)=z^5-1$$

# %%
cplot(lambda z:z**5-1)

# %% [markdown]
# # 7 Limites et séries

# %% [markdown]
# ### 7.1 Limites

# %%
from sympy.abc import x

# %%
limit(1/x, x, 0, dir='+')
# Out:
# ∞

# %%
oo
# Out:
# ∞

# %%
limit(1/x, x, oo)
# Out:
# 0

# %% [markdown]
# ### 7.2 Sommes et séries

# %% [markdown]
# ### 7.3 Produit

# %% [markdown]
# ### 7.4 Développement en séries
